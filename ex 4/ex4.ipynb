# %%
import pandas as pd
df = pd.read_csv(r"/content/AirPassengers (1).csv")


# Convert 'Month' column to datetime format
df['Month'] = pd.to_datetime(df['Month'], errors='coerce')

# Set 'Month' as index
df.set_index('Month', inplace=True)

# Aggregation - Monthly & Yearly Average
df_monthly = df['#Passengers'].resample('M').mean()
df_yearly = df['#Passengers'].resample('Y').mean()

# Moving Average Smoothing (Rolling Mean)
df['Moving_Avg'] = df['#Passengers'].rolling(window=12).mean()

# Exponential Smoothing
df['Exp_Smooth'] = df['#Passengers'].ewm(span=12, adjust=False).mean()

# Plot Original vs Aggregated & Smoothed Data
plt.figure(figsize=(12, 6))
plt.plot(df['#Passengers'], label="Original Data", alpha=0.5)
plt.plot(df['Moving_Avg'], label="Moving Avg (12-month)", color='red')
plt.plot(df['Exp_Smooth'], label="Exponential Smoothing", color='green')
plt.xlabel("Date")
plt.ylabel("Number of Passengers")
plt.title("Trend Estimation & Elimination using Smoothing")
plt.legend()
plt.show()
# Out:
# <ipython-input-9-d09fdbaa92ff>:12: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly = df['#Passengers'].resample('M').mean()
# <ipython-input-9-d09fdbaa92ff>:13: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_yearly = df['#Passengers'].resample('Y').mean()

# %%
import pandas as pd
import matplotlib.pyplot as plt # Importing the matplotlib library

df = pd.read_csv(r"/content/AirPassengers (1).csv")


# Convert 'Month' column to datetime format
df['Month'] = pd.to_datetime(df['Month'], errors='coerce')

# Set 'Month' as index
df.set_index('Month', inplace=True)

# Aggregation - Monthly & Yearly Average
import pandas as pd
import matplotlib.pyplot as plt # Importing the matplotlib library

df = pd.read_csv(r"/content/AirPassengers (1).csv")


# Convert 'Month' column to datetime format
df['Month'] = pd.to_datetime(df['Month'], errors='coerce')

# Set 'Month' as index
df.set_index('Month', inplace=True)

# Aggregation - Monthly & Yearly Average
df_monthly = df['#Passengers'].resample('M').mean()
df_yearly = df['#Passengers'].resample('Y').mean()

# Moving Average Smoothing (Rolling Mean)
df['Moving_Avg'] = df['#Passengers'].rolling(window=12).mean()

# Exponential Smoothing
df['Exp_Smooth'] = df['#Passengers'].ewm(span=12, adjust=False).mean()

# Plot Original vTrend Estimation & Elimination using Smoothing")
plt.figure(figsize=(12, 6)) # Now plt is defined and can be used
plt.plot(df['#Passengers'], label="Original Data", alpha=0.5)
plt.plot(df['Moving_Avg'], label="Moving Avg (12-month)", color='red')
plt.plot(df['Exp_Smooth'], label="Exponential Smoothing", color='green')
plt.xlabel("Date")
plt.ylabel("Number of Passengers")
plt.title("Trend Estimation & Elimination using Smoothing")
plt.legend()
plt.show()
df['Moving_Avg'] = df['#Passengers'].rolling(window=12).mean()

# Exponential Smoothing
df['Exp_Smooth'] = df['#Passengers'].ewm(span=12, adjust=False).mean()
import pandas as pd
import matplotlib.pyplot as plt # Importing the matplotlib library

df = pd.read_csv(r"/content/AirPassengers (1).csv")


# Convert 'Month' column to datetime format
df['Month'] = pd.to_datetime(df['Month'], errors='coerce')

# Set 'Month' as index
df.set_index('Month', inplace=True)

# Aggregation - Monthly & Yearly Average
df_monthly = df['#Passengers'].resample('M').mean()
df_yearly = df['#Passengers'].resample('Y').mean()

# Moving Average Smoothing (Rolling Mean)
df['Moving_Avg'] = df['#Passengers'].rolling(window=12).mean()

# Exponential Smoothing
df['Exp_Smooth'] = df['#Passengers'].ewm(span=12, adjust=False).mean()

# Plot Original vTrend Estimation & Elimination using Smoothing")
plt.figure(figsize=(12, 6)) # Now plt is defined and can be used
plt.plot(df['#Passengers'], label="Original Data", alpha=0.5)
plt.plot(df['Moving_Avg'], label="Moving Avg (12-month)", color='red')
plt.plot(df['Exp_Smooth'], label="Exponential Smoothing", color='green')
plt.xlabel("Date")
plt.ylabel("Number of Passengers")
plt.title("Trend Estimation & Elimination using Smoothing")
plt.legend()
plt.show()
plt.plot(df['Moving_Avg'], label="Moving Avg (12-month)", color='red')
plt.plot(df['Exp_Smooth'], label="Exponential Smoothing", color='green')
import pandas as pd
import matplotlib.pyplot as plt # Importing the matplotlib library

df = pd.read_csv(r"/content/AirPassengers (1).csv")


# Convert 'Month' column to datetime format
df['Month'] = pd.to_datetime(df['Month'], errors='coerce')

# Set 'Month' as index
df.set_index('Month', inplace=True)

# Aggregation - Monthly & Yearly Average
df_monthly = df['#Passengers'].resample('M').mean()
df_yearly = df['#Passengers'].resample('Y').mean()

# Moving Average Smoothing (Rolling Mean)
df['Moving_Avg'] = df['#Passengers'].rolling(window=12).mean()

# Exponential Smoothing
df['Exp_Smooth'] = df['#Passengers'].ewm(span=12, adjust=False).mean()

# Plot Original vTrend Estimation & Elimination using Smoothing")
plt.figure(figsize=(12, 6)) # Now plt is defined and can be used
plt.plot(df['#Passengers'], label="Original Data", alpha=0.5)
plt.plot(df['Moving_Avg'], label="Moving Avg (12-month)", color='red')
plt.plot(df['Exp_Smooth'], label="Exponential Smoothing", color='green')
plt.xlabel("Date")
plt.ylabel("Number of Passengers")
plt.title("Trend Estimation & Elimination using Smoothing")
plt.legend()
plt.show()

# Convert 'Month' column to datetime format
df['Month'] = pd.to_datetime(df['Month'], errors='coerce')

# Set 'Month' as index
df.set_index('Month', inplace=True)

# Aggregation - Monthly & Yearly Average
df_monthly = df['#Passengers'].resample('M').mean()
df_yearly = df['#Passengers'].resample('Y').mean()

# Moving Average Smoothing (Rolling Mean)
df['Moving_Avg'] = df['#Passengers'].rolling(window=12).mean()

# Exponential Smoothing
df['Exp_Smooth'] = df['#Passengers'].ewm(span=12, adjust=False).mean()

# Plot Original vTrend Estimation & Elimination using Smoothing")
plt.figure(figsize=(12, 6)) # Now plt is defined and can be used
plt.plot(df['#Passengers'], label="Original Data", alpha=0.5)
plt.plot(df['Moving_Avg'], label="Moving Avg (12-month)", color='red')
plt.plot(df['Exp_Smooth'], label="Exponential Smoothing", color='green')
plt.xlabel("Date")
plt.ylabel("Number of Passengers")
plt.title("Trend Estimation & Elimination using Smoothing")
plt.legend()
plt.show()
# Out:
#   File "<ipython-input-8-4c7da4a5844d>", line 52
#     plt.legendws Aggregated & Smoothed Data
#                  ^
# SyntaxError: invalid syntax
