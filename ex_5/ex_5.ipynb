# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

# Load the dataset
df = pd.read_csv("/content/us_air_pollution_2012_2021_updated.csv")

# Convert 'Date' column to datetime and set it as index
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df.set_index('Date', inplace=True)

# Select the pollution column (e.g., "PM2.5 (µg/m³)")
pollution_col = "PM2.5 (µg/m³)"

# 1. Visual Inspection (Rolling Statistics)
plt.figure(figsize=(10, 5))
plt.plot(df[pollution_col], label="Original Data")
plt.plot(df[pollution_col].rolling(window=12).mean(), label="Rolling Mean", color='red')
plt.plot(df[pollution_col].rolling(window=12).std(), label="Rolling Std Dev", color='black')
plt.legend()
plt.title("Rolling Mean & Standard Deviation")
plt.show()

# 2. Augmented Dickey-Fuller (ADF) Test
result = adfuller(df[pollution_col].dropna())
print(f"ADF Test Statistic: {result[0]}")
print(f"P-value: {result[1]}")
print("Critical Values:", result[4])

if result[1] < 0.05:
    print("The data is stationary (Reject H0).")
else:
    print("The data is non-stationary (Fail to Reject H0).")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-eb37a6f8c45d> in <cell line: 0>()
#       4
#       5 # Load the dataset
# ----> 6 df = pd.read_csv("/content/us_air_pollution_2012_2021_updated.csv")
#       7
#       8 # Convert 'Date' column to datetime and set it as index
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

# Load the AirPassengers dataset
data = pd.read_csv('AirPassengers.csv', index_col='Month', parse_dates=True)
# Extract the 'Passengers' column
passengers = data['#Passengers']

# Plot the time series
plt.figure(figsize=(10, 5))
plt.plot(passengers, label="Original Data")
plt.plot(passengers.rolling(window=12).mean(), label="Rolling Mean", color='red')
plt.plot(passengers.rolling(window=12).std(), label="Rolling Std Dev", color='black')
plt.legend()
plt.title("Rolling Mean & Standard Deviation")
plt.show()

# Perform the Augmented Dickey-Fuller test
result = adfuller(passengers)
print(f"ADF Test Statistic: {result[0]}")
print(f"P-value: {result[1]}")
print("Critical Values:", result[4])

if result[1] < 0.05:
    print("The data is stationary (Reject H0).")
else:
    print("The data is non-stationary (Fail to Reject H0).")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-ee298fac1c73> in <cell line: 0>()
#       4
#       5 # Load the AirPassengers dataset
# ----> 6 data = pd.read_csv('AirPassengers.csv', index_col='Month', parse_dates=True)
#       7 # Extract the 'Passengers' column
#       8 passengers = data['#Passengers']
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

# Load the AirPassengers dataset
# The original code tried to use 'Month' as the index column
# but it seems the column name in the file is actually 'Month'.
data = pd.read_csv('AirPassengers.csv', index_col='Month', parse_dates=True)
# Extract the 'Passengers' column
passengers = data['#Passengers']

# Plot the time series
plt.figure(figsize=(10, 5))
plt.plot(passengers, label="Original Data")
plt.plot(passengers.rolling(window=12).mean(), label="Rolling Mean", color='red')
plt.plot(passengers.rolling(window=12).std(), label="Rolling Std Dev", color='black')
plt.legend()
plt.title("Rolling Mean & Standard Deviation")
plt.show()

# Perform the Augmented Dickey-Fuller test
result = adfuller(passengers)
print(f"ADF Test Statistic: {result[0]}")
print(f"P-value: {result[1]}")
print("Critical Values:", result[4])

if result[1] < 0.05:
    print("The data is stationary (Reject H0).")
else:
    print("The data is non-stationary (Fail to Reject H0).")
# Out:
# ADF Test Statistic: 0.8153688792060498
# P-value: 0.991880243437641
# Critical Values: {'1%': np.float64(-3.4816817173418295), '5%': np.float64(-2.8840418343195267), '10%': np.float64(-2.578770059171598)}
# The data is non-stationary (Fail to Reject H0).
